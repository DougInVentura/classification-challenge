# %% [markdown]
# # Spam Detector

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Retrieve the Data
#
# The data is located at [https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv](https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv)
#
# Dataset Source: [UCI Machine Learning Library](https://archive.ics.uci.edu/dataset/94/spambase)
#
# Import the data using Pandas. Display the resulting DataFrame to confirm the import was successful.

# %%
# Import the data
data = pd.read_csv("https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv")
data.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# 0             0.00            0.00  ...         0.00        0.000
# ...

# %% [markdown]
# #### Note in starter code. Prior to making a guess as to which model will work better, I want to see what data we have using standard dataframe information methods or attributes

# %%
print("Info")
display(data.info())
print("\nDescribe")
display(data.describe())
print("\n\nNumber of nulls")
display(data.isna().sum())
# Out:
# Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4601 entries, 0 to 4600
# Data columns (total 58 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   word_freq_make              4601 non-null   float64
#  1   word_freq_address           4601 non-null   float64
#  2   word_freq_all               4601 non-null   float64
#  3   word_freq_3d                4601 non-null   float64
#  4   word_freq_our               4601 non-null   float64
#  5   word_freq_over              4601 non-null   float64
#  6   word_freq_remove            4601 non-null   float64
#  7   word_freq_internet          4601 non-null   float64
#  8   word_freq_order             4601 non-null   float64
#  9   word_freq_mail              4601 non-null   float64
#  10  word_freq_receive           4601 non-null   float64
#  11  word_freq_will              4601 non-null   float64
# ...

# %% [markdown]
# ## Predict Model Performance
#
# You will be creating and comparing two models on this data: a Logistic Regression, and a Random Forests Classifier. Before you create, fit, and score the models, make a prediction as to which model you think will perform better. You do not need to be correct!
#
# Write down your prediction in the designated cells in your Jupyter Notebook, and provide justification for your educated guess.

# %% [markdown]
# #### My guess is the Random Forest will provide a better fit. This guess is based on the following:
# 1) Random Forest is an ensemble method, which has some advantages.
# 2) On the other hand, it looks like most of the data is floating point, which is very compatible with using a regression based classifier.
# 3) If there is curvature (quadratic or otherwise), this would hurt the Logistic Regression (LR) model.  Conversely, the Random Forest model would not be affected.
# 4) On several other datasets, Random Forest has had better accuracy scores.  Conversely, I did a side project on the Wisconsin Breast Cancer dataset and Logistic Regression vested Random Forest.
# 5) All of this is to say, I will guess that Random Forest will prevail, but it is a guess and this is why it is preferrable to try various models to see which performs better.

# %% [markdown]
# ## Split the Data into Training and Testing Sets

# %%
# Create the labels set `y` and features DataFrame `X`
X = data.copy()
X.drop(columns=['spam'], inplace=True)
y = data[['spam']]

# %%
# Check the balance of the labels variable (`y`) by using the `value_counts` function.
y.value_counts()
# Out:
# spam
# 0       2788
# 1       1813
# Name: count, dtype: int64

# %%
# Split the data into X_train, X_test, y_train, y_test
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=42)
X_train.head()
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 1173            0.00                0.0           0.00           0.0
# 1954            0.67                0.0           0.00           0.0
# 256             0.00                0.0           1.42           0.0
# 3341            0.00                0.0           0.24           0.0
# 4469            0.00                0.0           0.00           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 1173           0.00            0.00              1.23                0.00
# 1954           0.00            0.00              0.00                0.00
# 256            0.71            0.00              0.00                0.71
# 3341           0.09            0.04              0.00                0.00
# 4469           0.00            0.00              0.00                0.00
#
#       word_freq_order  word_freq_mail  ...  word_freq_conference  char_freq_;  \
# ...

# %% [markdown]
# ## Scale the Features

# %% [markdown]
# Use the `StandardScaler` to scale the features data. Remember that only `X_train` and `X_test` DataFrames should be scaled.

# %%
from sklearn.preprocessing import StandardScaler

# Create the StandardScaler instance
scaler = StandardScaler()
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
# Scale the training data
X_train_scaled = scaler.transform(X_train)
# will need to scale X_test to predict if needed.
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Create and Fit a Logistic Regression Model
#
# Create a Logistic Regression model, fit it to the training data, make predictions with the testing data, and print the model's accuracy score. You may choose any starting settings you like.

# %%
# Train a Logistic Regression model and print the model score
from sklearn.linear_model import LogisticRegression
clf_LR = LogisticRegression()
clf_LR.fit(X_train_scaled, y_train)
model_score_train_LR = clf_LR.score(X_train_scaled,y_train) * 100
model_score_test_LR = clf_LR.score(X_test_scaled,y_test) * 100
print("Data below is from the model.score function")
print(f"Accuracy Score for Logistic Regression using Training Data is: {model_score_train_LR:.2f} %")
print(f"Accuracy Score for Logistic Regression using TEST Data is:     {model_score_test_LR:.2f} %")
# Out:
# Data below is from the model.score function
# Accuracy Score for Logistic Regression using Training Data is: 92.58 %
# Accuracy Score for Logistic Regression using TEST Data is:     92.27 %
# c:\ProgramData\anaconda3\envs\dev\lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# Make and save testing predictions with the saved logistic regression model using the test data
y_pred_test_LR = clf_LR.predict(X_test_scaled)
# Review the predictions
y_pred_test_LR
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
# Calculate the accuracy score by evaluating `y_test` vs. `testing_predictions`.
accuracy_score_test_LR = accuracy_score(y_test, y_pred_test_LR) * 100
print("The score below is from the accuracy_score method in sklearn.metrics")
print(f"Accuracy Score for Logistic Regression using TEST Data is: {accuracy_score_test_LR:.2f} %")
# Out:
# The score below is from the accuracy_score method in sklearn.metrics
# Accuracy Score for Logistic Regression using TEST Data is: 92.27 %

# %% [markdown]
# ## Create and Fit a Random Forest Classifier Model
#
# Create a Random Forest Classifier model, fit it to the training data, make predictions with the testing data, and print the model's accuracy score. You may choose any starting settings you like.

# %%
# Train a Random Forest Classifier model and print the model score
from sklearn.ensemble import RandomForestClassifier
clf_RF = RandomForestClassifier()
clf_RF.fit(X_train_scaled, y_train)
# Out:
# c:\ProgramData\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier()

# %%
# Make and save testing predictions with the saved logistic regression model using the test data
y_pred_test_RF = clf_RF.predict(X_test_scaled)

# Review the predictions
y_pred_test_RF
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
# Calculate the accuracy score by evaluating `y_test` vs. `testing_predictions`.
accuracy_score_test_RF = accuracy_score(y_test, y_pred_test_RF) * 100
print("The score below is from the accuracy_score method in sklearn.metrics")
print(f"Accuracy Score for Logistic Regression using TEST Data is: {accuracy_score_test_RF:.2f} %")
# Out:
# The score below is from the accuracy_score method in sklearn.metrics
# Accuracy Score for Logistic Regression using TEST Data is: 95.74 %

# %%
# Calculate the accuracy score by evaluating `y_test` vs. `testing_predictions`.
accuracy_score_test_RF = accuracy_score(y_test, y_pred_test_RF)
# Out:
# 0.9548218940052129

# %% [markdown]
# ## Evaluate the Models
#
# Which model performed better? How does that compare to your prediction? Write down your results and thoughts in the following markdown cell.

# %% [markdown]
# My prediction was that the random forest would perform better.  This prediction / guess was correct.  It is consistent with perhaps 4 out of 5 datasets I have seen analyzed using both of these methods.
# Ensemble methods do have the advantage of using multiple models and either voting or averaging the results to obtain final predictions.
